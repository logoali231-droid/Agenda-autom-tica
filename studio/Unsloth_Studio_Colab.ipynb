# %% [markdown]
# <a href="https://colab.research.google.com/github/logoali231-droid/Agenda-autom-tica/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Unsloth Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 3811, done.
# remote: Counting objects: 100% (3811/3811), done.
# remote: Compressing objects: 100% (3618/3618), done.
# remote: Total 3811 (delta 217), reused 1987 (delta 158), pack-reused 0 (from 0)
# Receiving objects: 100% (3811/3811), 48.98 MiB | 16.17 MiB/s, done.
# Resolving deltas: 100% (217/217), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  installing isolated Node (system Node/npm left untouched)...
#   node           v24.18.0 | npm 11.16.0 (isolated)
#                  installing bun...
#                  bun installed (1.3.14)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Unsloth backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/16  base packages
#   deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [=======-------------]  6/16  dependency overrides
#                  torch 2.11.0+cu128 detected -- installing torchao==0.17.0
#   deps           [====================] 16/16  torch final (cuda)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   transformers   5.10.2 pre-installed
#   gpu            NVIDIA GPU detected
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b10360-mix-87da1a2 (tag b10360)
#   whisper.cpp    prebuilt installed
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start

# On Colab, start() auto-opens a Cloudflare link and prints admin login credentials.
# Use the Cloudflare link above the ready card to open Studio (in-cell iframes often stay blank).
start()

# To skip the Cloudflare tunnel and try the in-notebook proxy iframe only:
# start(cloudflare=False)
# Out:
# 2026-08-13 12:11:58 [info     ] 🦥 Starting Unsloth Studio...
# {"timestamp": "2026-08-13T12:12:05.475153Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-08-13T12:12:05.513656Z", "level": "info", "event": "   Starting server..."}
# {"timestamp": "2026-08-13T12:12:05.516722Z", "level": "info", "event": "run_server startup begin api_only=False host=0.0.0.0 port=8888"}
# {"timestamp": "2026-08-13T12:12:05.570463Z", "level": "info", "event": "Imported FastAPI app in 2.3ms"}
# {"timestamp": "2026-08-13T12:12:05.574488Z", "level": "info", "event": "Ensured Unsloth directories in 57.8ms"}
# {"timestamp": "2026-08-13T12:12:05.826646Z", "level": "info", "event": "run_server pre-uvicorn setup completed in 309.9ms"}
# INFO:     Started server process [970]
# INFO:     Waiting for application startup.
# {"timestamp": "2026-08-13T12:12:06.217764Z", "level": "info", "event": "Removing unsloth compiled cache: /root/.unsloth/studio/compiled_cache"}
# {"timestamp": "2026-08-13T12:12:06.617186Z", "level": "info", "event": "lifespan pre-auth setup completed in 402.4ms"}
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Unsloth UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-08-13T12:12:06.843382Z", "level": "info", "event": "lifespan startup completed in 628.6ms"}
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://35.198.246.218:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# {"timestamp": "2026-08-13T12:12:06.864717Z", "level": "info", "event": "Uvicorn startup hook completed in 1348.0ms"}
# {"timestamp": "2026-08-13T12:12:06.876488Z", "level": "info", "event": "run_server uvicorn ready after 1359.8ms"}
# {"timestamp": "2026-08-13T12:12:07.740710Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-08-13T12:12:09.256861Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1502.02}
# Hardware detected: CUDA -- Tesla T4
# {"timestamp": "2026-08-13T12:12:09.853939Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-08-13T12:12:23.484711Z", "level": "info", "event": "torch warm finished in 16641.8ms"}
# {"timestamp": "2026-08-13T12:13:04.593438Z", "level": "info", "event": "Cloudflare tunnel did not produce a URL; using Colab proxy only."}
# {"timestamp": "2026-08-13T12:13:10.158813Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-ass1a2-106oj0uul0idl-a.asia-southeast1-2.prod.colab.dev"}
# {"timestamp": "2026-08-13T12:13:10.159790Z", "level": "warning", "event": "Colab Cloudflare tunnel unavailable \u2014 Studio is unlikely to be reachable in this notebook. Check the logs above for tunnel or auth errors, then re-run start()."}
# {"timestamp": "2026-08-13T12:13:10.160713Z", "level": "info", "event": "\ud83d\udd10 Unsloth Studio login \u2014 user: unsloth"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 22px; font-weight: 800;">
#             Unsloth Studio Login (Colab)
#         </h2>
#         <p style="color: #333333; margin: 0 0 12px 0; font-size: 14px; font-weight: bold;">
#             Log in as <code>unsloth</code> with this password. This cell is visible only in
#             your notebook session.
#         </p>
#         <p style="color: #333333; margin: 0; font-size: 14px; font-family: monospace; font-weight: bold;">
#             Password: <code>FrostlikeCactusScouringItalicize</code>
#         </p>
#     </div>
# {"timestamp": "2026-08-13T12:13:10.164565Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-ass1a2-106oj0uul0idl-a.asia-southeast1-2.prod.colab.dev"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <p style="color: #333333; margin: 0 0 8px 0; font-size: 15px; font-weight: bold;">
#             Could not open a Cloudflare tunnel, so Studio may be unreachable on Colab. Check the logs above and re-run this cell. Pass <code style="background:#f3f3f3;padding:2px 6px;border-radius:4px;">cloudflare=True</code> after fixing any tunnel errors.
#         </p>
#         <p style="color: #666666; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             https://8888-gpu-...
#         </p>
#     </div>
# {"timestamp": "2026-08-13T12:13:10.718130Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 3.56}
# {"timestamp": "2026-08-13T12:13:25.329102Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/theme-boot.js", "status_code": 200, "process_time_ms": 46.92}
# {"timestamp": "2026-08-13T12:13:28.951799Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 2.11}
# {"timestamp": "2026-08-13T12:13:29.707414Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 5.02}
# {"timestamp": "2026-08-13T12:15:28.037076Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 152.22}
# {"timestamp": "2026-08-13T12:15:28.599651Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 4.5}
# {"timestamp": "2026-08-13T12:15:28.821242Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 10.46}
# {"timestamp": "2026-08-13T12:15:28.957733Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 10.15}
# {"timestamp": "2026-08-13T12:15:28.962483Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 9.56}
# {"timestamp": "2026-08-13T12:15:30.115356Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 1141.06}
# {"timestamp": "2026-08-13T12:15:30.127713Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 1142.64}
# {"timestamp": "2026-08-13T12:15:30.142743Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.91}
# {"timestamp": "2026-08-13T12:15:30.186777Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-08-13T12:15:30.190855Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-08-13T12:15:30.196091Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 44.75}
# {"timestamp": "2026-08-13T12:15:30.466616Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/Qwen3.6-27B-MTP-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/gemma-4-12b-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-MTP-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/gemma-4-26B-A4B-it-qat-GGUF', 'unsloth/Qwen-AgentWorld-35B-A3B-GGUF', 'unsloth/gemma-4-E4B-it-qat-GGUF', 'unsloth/Kimi-K3-GGUF', 'unsloth/Muse-Glimmer-30B-GGUF', 'unsloth/bge-small-en-v1.5-GGUF', 'unsloth/gemma-4-12B-it-qat-GGUF', 'unsloth/inkling-GGUF', 'unsloth/Qwen3-30B-A3B-Instruct-2507-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/DeepSeek-V4-Flash-0731-GGUF', 'unsloth/gemma-4-31B-it-qat-GGUF', 'unsloth/Inkling-Small-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/Ornith-1.0-35B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/Laguna-S-2.1-GGUF', 'unsloth/gemma-4-E2B-it-qat-GGUF', 'unsloth/GLM-5.2-GGUF', 'unsloth/Kimi-K2.7-Code-GGUF', 'unsloth/Qwen3-8B-GGUF', 'unsloth/Qwen3-30B-A3B-Thinking-2507-GGUF', 'unsloth/Qwen3-235B-A22B-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3.5-27B-GGUF']"}
# {"timestamp": "2026-08-13T12:15:30.467718Z", "level": "info", "event": "Top hub models: ['unsloth/Qwen3.6-27B-NVFP4', 'unsloth/Qwen3.6-35B-A3B-NVFP4', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/gemma-4-E4B-it-unsloth-bnb-4bit', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3.6-35B-A3B-NVFP4-Fast', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Qwen2.5-14B-Instruct', 'unsloth/Qwen3-Embedding-4B', 'unsloth/GLM-4.7-Flash', 'unsloth/bge-small-en-v1.5', 'unsloth/GLM-4.5-Air', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-VL-32B-Instruct-bnb-4bit', 'unsloth/Qwen2.5-14B-bnb-4bit', 'unsloth/gemma-4-26B-A4B-it-NVFP4', 'unsloth/llava-1.5-7b-hf-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen3-0.6B', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen3-VL-2B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-1.7B', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen3-8B', 'unsloth/Qwen3.5-9B', 'unsloth/Qwen2.5-Coder-1.5B-Instruct', 'unsloth/Qwen2.5-1.5B-Instruct-unsloth-bnb-4bit']"}
# {"timestamp": "2026-08-13T12:15:30.507755Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 6.07}
# {"timestamp": "2026-08-13T12:15:30.978300Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings
z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/cached", "status_code": 200, "process_time_ms": 13.06}
# {"timestamp": "2026-08-13T12:19:20.176610Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-08-13T12:19:20.182864Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 13.71}
# {"timestamp": "2026-08-13T12:19:20.191023Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 26.33}
# {"timestamp": "2026-08-13T12:19:20.193784Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 6.64}
# {"timestamp": "2026-08-13T12:19:28.924388Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-08-13T12:19:30.948894Z", "level": "info", "event": "Checking format for dataset: llama"}
# {"timestamp": "2026-08-13T12:19:31.509658Z", "level": "info", "event": "torchcodec is installed but unusable (Could not load libtorchcodec. Likely causes:\n          1. FFmpeg is not properly installed in your environment. We support\n             versions 4, 5, 6, 7, and 8, and we attempt to load libtorchcodec\n             for each of those versions. Errors for versions not installed on\n             your system are expected; only the error for your installed FFmpeg\n             version is relevant. On Windows, ensure you've installed the\n             \"full-shared\" version which ships DLLs.\n          2. The PyTorch version (2.11.0+cu128) is not compatible with\n             this version of TorchCodec. Refer to the version compatibility\n             table:\n             https://github.com/pytorch/torchcodec?tab=readme-ov-file#installing-torchcodec.\n          3. Another runtime dependency; see exceptions below.\n\n        The following exceptions were raised as we tried to load libtorchcodec:\n        \n[start of libtorchcodec loading traceback]\nFFmpeg version 8:\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/torch/_ops.py\", line 1503, in load_library\n    ctypes.CDLL(path)\n  File \"/usr/lib/python3.12/ctypes/__init__.py\", line 379, in __init__\n    self._handle = _dlopen(self._name, mode)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^\nOSError: libavutil.so.60: cannot open shared object file: No such file or directory\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-\n... [3778 chars omitted; raise UNSLOTH_STUDIO_MAX_EXCEPTION_CHARS to see it all] ...\n\n\nTraceback (most recent call last):\n  File \"/usr/local/lib/python3.12/dist-packages/torchcodec/_core/ops.py\", line 57, in load_torchcodec_shared_libraries\n    torch.ops.load_library(core_library_path)\n  File \"/usr/local/lib/python3.12/dist-packages/torch/_ops.py\", line 1505, in load_library\n    raise OSError(f\"Could not load this library: {path}\") from e\nOSError: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchcodec/libtorchcodec_core4.so\n[end of libtorchcodec loading traceback].)"}
# {"timestamp": "2026-08-13T12:19:31.550960Z", "level": "info", "event": "torchcodec is unusable; decoding dataset audio with soundfile"}
# {"timestamp": "2026-08-13T12:19:31.795194Z", "level": "warning", "event": "Tier 1 (single-file) failed: 401 Client Error. (Request ID: Root=1-6a7db653-3c27311822243e4934b4e0bc;f5ec6e8e-a812-4064-af36-ce283d85fb1e)\n\nRepository Not Found for url: https://huggingface.co/api/datasets/llama/tree/main?recursive=true&expand=false.\nPlease make sure you specified the correct `repo_id` and `repo_type`.\nIf you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.\nFor more details, see https://huggingface.co/docs/huggingface_hub/authentication\nInvalid username or password."}
# {"timestamp": "2026-08-13T12:19:31.796181Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-08-13T12:19:32.036398Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/datasets/check-format", "status_code": 404, "process_time_ms": 1092.16}
# {"timestamp": "2026-08-13T12:19:39.735843Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.38}
# {"timestamp": "2026-08-13T12:19:50.624475Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.86}
# {"timestamp": "2026-08-13T12:20:00.353206Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 9.17}
# {"timestamp": "2026-08-13T12:20:00.370982Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-08-13T12:20:00.377902Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 19.54}
# {"timestamp": "2026-08-13T12:20:00.379910Z", "level": "info", "event": "Cached dataset scan: roots=1 inspected=0 returned=0"}
# {"timestamp": "2026-08-13T12:20:00.387677Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/cached", "status_code": 200, "process_time_ms": 23.83}
# {"timestamp": "2026-08-13T12:20:00.390090Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 15.69}
# {"timestamp": "2026-08-13T12:20:00.393556Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 26.15}
# {"timestamp": "2026-08-13T12:20:01.429487Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.5}
# {"timestamp": "2026-08-13T12:20:12.347868Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.48}
# {"timestamp": "2026-08-13T12:20:23.224631Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.03}
# {"timestamp": "2026-08-13T12:20:26.768063Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/images/gallery", "status_code": 200, "process_time_ms": 171.02}
# {"timestamp": "2026-08-13T12:20:27.604488Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/images/load-progress", "status_code": 200, "process_time_ms": 2.44}
# {"timestamp": "2026-08-13T12:20:28.005930Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/images/generate-progress", "status_code": 200, "process_time_ms": 2.76}
# {"timestamp": "2026-08-13T12:20:30.970470Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 4.96}
# {"timestamp": "2026-08-13T12:20:31.155872Z", "level": "info", "event": "Checking format for dataset: llama"}
# {"timestamp": "2026-08-13T12:20:31.398055Z", "level": "warning", "event": "Tier 1 (single-file) failed: 401 Client Error. (Request ID: Root=1-6a7db68f-54a1a070581265140e435afa;35b86666-bc02-4553-a166-6d307f231e57)\n\nRepository Not Found for url: https://huggingface.co/api/datasets/llama/tree/main?recursive=true&expand=false.\nPlease make sure you specified the correct `repo_id` and `repo_type`.\nIf you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.\nFor more details, see https://huggingface.co/docs/huggingface_hub/authentication\nInvalid username or password."}
# {"timestamp": "2026-08-13T12:20:31.399022Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-08-13T12:20:31.652069Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/datasets/check-format", "status_code": 404, "process_time_ms": 499.98}
# {"timestamp": "2026-08-13T12:20:31.705558Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-08-13T12:20:31.706318Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 13.94}
# {"timestamp": "2026-08-13T12:20:31.708804Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 19.24}
# {"timestamp": "2026-08-13T12:20:31.722627Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 11.76}
# {"timestamp": "2026-08-13T12:20:31.733154Z", "level": "info", "event": "Cached dataset scan: roots=1 inspected=0 returned=0"}
# {"timestamp": "2026-08-13T12:20:31.737078Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/cached", "status_code": 200, "process_time_ms": 18.27}
# {"timestamp": "2026-08-13T12:20:31.741238Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 26.21}
# {"timestamp": "2026-08-13T12:20:34.166982Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.56}
# {"timestamp": "2026-08-13T12:20:45.030657Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.28}
# {"timestamp": "2026-08-13T12:20:51.510722Z", "level": "info", "event": "Getting model config for: unsloth/Llama-3.2-3B-Instruct"}
# {"timestamp": "2026-08-13T12:20:51.517924Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/llama/unsloth_Llama-3.2-3B-Instruct.yaml"}
# {"timestamp": "2026-08-13T12:20:51.531313Z", "level": "info", "event": "Checking format for dataset: llama"}
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# {"timestamp": "2026-08-13T12:20:51.774086Z", "level": "warning", "event": "Tier 1 (single-file) failed: 401 Client Error. (Request ID: Root=1-6a7db6a3-25a21639558c4a1c60169724;a62d4342-0f43-4306-95ee-f32781822edc)\n\nRepository Not Found for url: https://huggingface.co/api/datasets/llama/tree/main?recursive=true&expand=false.\nPlease make sure you specified the correct `repo_id` and `repo_type`.\nIf you are trying to access a private or gated repo, make sure you are authenticated and your token has the required permissions.\nFor more details, see https://huggingface.co/docs/huggingface_hub/authentication\nInvalid username or password."}
# {"timestamp": "2026-08-13T12:20:51.774815Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-08-13T12:20:52.017745Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/datasets/check-format", "status_code": 404, "process_time_ms": 490.56}
# {"timestamp": "2026-08-13T12:20:52.313886Z", "level": "info", "event": "Transformers tier default (4.57.x) selected for unsloth/Llama-3.2-3B-Instruct (no match)"}
# {"timestamp": "2026-08-13T12:20:53.546362Z", "level": "info", "event": "Model config result for unsloth/Llama-3.2-3B-Instruct: is_vision=False, is_embedding=False, audio_type=None, audio_type_known=True, is_lora=False, max_position_embeddings=131072"}
# {"timestamp": "2026-08-13T12:20:53.782272Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Llama-3.2-3B-Instruct", "status_code": 200, "process_time_ms": 2325.1}
# {"timestamp": "2026-08-13T12:20:55.855395Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.65}
# {"timestamp": "2026-08-13T12:21:06.806149Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.62}
# {"timestamp": "2026-08-13T12:21:11.421592Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 16.37}
# {"timestamp": "2026-08-13T12:21:11.441333Z", "level": "info", "event": "Cached model scan: inspected=1 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-08-13T12
Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/Llama-3.2-3B-Instruct", "status_code": 200, "process_time_ms": 874.57}
# {"timestamp": "2026-08-13T14:53:05.696207Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 4.61}
# ={"timestamp": "2026-08-13T14:53:10.335381Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.69}
# {"timestamp": "2026-08-13T14:53:21.150828Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.93}
# {"timestamp": "2026-08-13T14:53:32.105339Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.78}
# {"timestamp": "2026-08-13T14:53:42.902792Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 4.32}
# {"timestamp": "2026-08-13T14:54:13.878757Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/datasets/local", "status_code": 200, "process_time_ms": 5.4}
# {"timestamp": "2026-08-13T14:54:14.796192Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 4.38}
# {"timestamp": "2026-08-13T14:54:25.598537Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 4.08}
# {"timestamp": "2026-08-13T14:54:41.351701Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.54}
# {"timestamp": "2026-08-13T14:54:52.593652Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.92}
# {"timestamp": "2026-08-13T14:55:11.882850Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.24}
# {"timestamp": "2026-08-13T14:56:09.087619Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 5.49}
# {"timestamp": "2026-08-13T14:56:09.608455Z", "level": "info", "event": "Getting model config for: root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642"}
# {"timestamp": "2026-08-13T14:56:09.622055Z", "level": "warning", "event": "Could not read config.json for 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642': Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642'. Use `repo_type` argument if needed."}
# {"timestamp": "2026-08-13T14:56:10.638043Z", "level": "info", "event": "Transformers tier default (4.57.x) selected for root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642 (no match)"}
# {"timestamp": "2026-08-13T14:56:10.641940Z", "level": "warning", "event": "Could not determine if root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642 is vision model: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642'. Use `repo_type` argument if needed."}
# {"timestamp": "2026-08-13T14:56:10.643055Z", "level": "warning", "event": "Could not determine if root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642 is embedding model: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642'. Use `repo_type` argument if needed."}
# {"timestamp": "2026-08-13T14:56:10.646202Z", "level": "error", "event": "models.get_model_config_failed: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642'. Use `repo_type` argument if needed.", "exception": "Traceback (most recent call last):\n  File \"/content/unsloth/studio/backend/utils/models/model_config.py\", line 3060, in is_embedding_model\n    info = hf_model_info(model_name, token = hf_token, timeout = _HUB_MODEL_INFO_TIMEOUT)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py\", line 84, in _inner_fn\n    validate_repo_id(arg_value)\n  File \"/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py\", line 132, in validate_repo_id\n    raise HFValidationError(\nhuggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642'. Use `repo_type` argument if needed.\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/content/unsloth/studio/backend/routes/models.py\", line 2239, in get_model_config\n    return await asyncio.to_thread(_resolve, model_name)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/threads.py\", line 25, in to_thread\n    return await loop.run_in_executor(None, func_call)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/futures.py\", line 289, in __await__\n    yield self  # This tells Task to wait for completion.\n    ^^^^^^^^^^\n  File \"/usr/lib/python3.12/asyncio/tasks.py\", line 385, in __wakeup\n    future.result()\n  File \"/usr/lib/python3.12/asyncio/futures.py\", line 202, in result\n    raise self._exception.with_traceback(self._exception_tb)\n  File \"/usr/lib/python3.12/concurrent/futures/thread.py\", line 59, in run\n    result = self.fn(*self.args, **self.kwargs)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/content/unsloth/studio/backend/routes/models.py\", line 2174, in _resolve\n    is_embedding = is_embedding_model(inspection_target, hf_token = hf_token)\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/content/unsloth/studio/backend/utils/models/model_config.py\", line 3083, in is_embedding_model\n    is_emb = _embedding_marker_in_hf_cache(model_name)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/content/unsloth/studio/backend/utils/models/model_config.py\", line 3015, in _embedding_marker_in_hf_cache\n    snapshot = hf_cache_snapshot_dir(model_name)\n               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/content/unsloth/studio/backend/utils/utils.py\", line 512, in hf_cache_snapshot_dir\n    folder = repo_folder_name(repo_id = repo_id, repo_type = \"model\")\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py\", line 84, in _inner_fn\n    validate_repo_id(arg_value)\n  File \"/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py\", line 132, in validate_repo_id\n    raise HFValidationError(\nhuggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642'. Use `repo_type` argument if needed."}
# | Traceback (most recent call last):
# |   File "/content/unsloth/studio/backend/utils/models/model_config.py", line 3060, in is_embedding_model
# |     info = hf_model_info(model_name, token = hf_token, timeout = _HUB_MODEL_INFO_TIMEOUT)
# |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 84, in _inner_fn
# |     validate_repo_id(arg_value)
# |   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 132, in validate_repo_id
# |     raise HFValidationError(
# | huggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642'. Use `repo_type` argument if needed.
# |
# | During handling of the above exception, another exception occurred:
# |
# | Traceback (most recent call last):
# |   File "/content/unsloth/studio/backend/routes/models.py", line 2239, in get_model_config
# |     return await asyncio.to_thread(_resolve, model_name)
# |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/usr/lib/python3.12/asyncio/threads.py", line 25, in to_thread
# |     return await loop.run_in_executor(None, func_call)
# |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/usr/lib/python3.12/asyncio/futures.py", line 289, in __await__
# |     yield self  # This tells Task to wait for completion.
# |     ^^^^^^^^^^
# |   File "/usr/lib/python3.12/asyncio/tasks.py", line 385, in __wakeup
# |     future.result()
# |   File "/usr/lib/python3.12/asyncio/futures.py", line 202, in result
# |     raise self._exception.with_traceback(self._exception_tb)
# |   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
# |     result = self.fn(*self.args, **self.kwargs)
# |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/content/unsloth/studio/backend/routes/models.py", line 2174, in _resolve
# |     is_embedding = is_embedding_model(inspection_target, hf_token = hf_token)
# |                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/content/unsloth/studio/backend/utils/models/model_config.py", line 3083, in is_embedding_model
# |     is_emb = _embedding_marker_in_hf_cache(model_name)
# |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/content/unsloth/studio/backend/utils/models/model_config.py", line 3015, in _embedding_marker_in_hf_cache
# |     snapshot = hf_cache_snapshot_dir(model_name)
# |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/content/unsloth/studio/backend/utils/utils.py", line 512, in hf_cache_snapshot_dir
# |     folder = repo_folder_name(repo_id = repo_id, repo_type = "model")
# |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 84, in _inner_fn
# |     validate_repo_id(arg_value)
# |   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 132, in validate_repo_id
# |     raise HFValidationError(
# | huggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642'. Use `repo_type` argument if needed.
# {"timestamp": "2026-08-13T14:56:10.653115Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/root/.unsloth/studio/outputs/unsloth_Llama-3.2-3B-Instruct_1786629642", "status_code": 500, "process_time_ms": 1089.25}
# {"timestamp": "2026-08-13T14:57:07.515674Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.97}
# {"timestamp": "2026-08-13T14:57:18.838264Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 7.36}

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
